# %%
import numpy as np
import faiss
import matplotlib.pyplot as plt

index_path = '../../tests/repos/index/moatless-claude-novars/vector_index_summary.faiss'

# Load the FAISS index
index = faiss.read_index(index_path)
# Get the total number of vectors in the index
invlists = faiss.extract_index_ivf(index).invlists
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_34924\1435306477.py in ?()
#       6
#       7 # Load the FAISS index
#       8 index = faiss.read_index(index_path)
#       9 # Get the total number of vectors in the index
# ---> 10 invlists = faiss.extract_index_ivf(index).invlists
#      11
#      12
#
# c:\Users\jpeng\Documents\projects\codeRAG\moatless-tools\.venv\lib\site-packages\faiss\swigfaiss_avx2.py in ?(*args)
#    6079 def extract_index_ivf(*args):
# -> 6080     return _swigfaiss_avx2.extract_index_ivf(*args)
#
# RuntimeError: Error in const IndexIVF *__cdecl faiss::ivflib::extract_index_ivf(const Index *) at D:\a\faiss-wheels\faiss-wheels\faiss\faiss\IVFlib.cpp:93: Error: 'ivf' failed

# %%
# Extract the original dimensionality and number of vectors
d = index.d
n = index.ntotal
d_target = 2

mat = faiss.PCAMatrix(d, d_target)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_34924\3535682589.py in ?()
#       5 # Retrieve the stored vectors
#       6 # Note: This assumes the vectors were added to the index in a contiguous block
#       7 vectors = np.zeros((n, d), dtype='float32')
#       8 for i in range(n):
# ----> 9     vectors[i] = index.reconstruct(i)
#      10
#      11 # Step 2: Create a FAISS index with PCA
#      12 pca_dim = 2  # reduce to 2 dimensions
#
# c:\Users\jpeng\Documents\projects\codeRAG\moatless-tools\.venv\lib\site-packages\faiss\class_wrappers.py in ?(self, key, x)
#     516             x = np.empty(self.d, dtype=np.float32)
#     517         else:
#     518             assert x.shape == (self.d, )
#     519
# --> 520         self.reconstruct_c(key, swig_ptr(x))
#     521         return x
#
# ...
